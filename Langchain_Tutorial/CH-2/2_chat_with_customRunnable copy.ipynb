# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage, SystemMessage,AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

from langchain_core.output_parsers import StrOutputParser
import os

# Load environment variables from .env file
load_dotenv()

llm_openai = ChatOpenAI(model = "deepseek-chat",
base_url="https://api.deepseek.com",
api_key=os.environ.get('DEEPSEEK_API_KEY'),
 temperature=0)


if os.environ.get('DEEPSEEK_API_KEY') :
    print("DEEPSEEK_API_KEY is set")
else:    print("DEEPSEEK_API_KEY is not set")
# Out:
# DEEPSEEK_API_KEY is set

# %% [markdown]
# # **CHAIN WITH CUSTOM RUNNABLE**

# %%
# TASK-1 prompt

prompt_template = ChatPromptTemplate.from_messages(
[("system", "You are a helpful assistant"),
("human", "{input}")])

# %%
# TASK-2  LLM


# llm_openai = ChatOpenAI(model = "deepseek-chat",
# base_url="https://api.deepseek.com",
# api_key=os.environ.get('DEEPSEEK_API_KEY'),
#  temperature=0)

# %%
# TASK-3  StrParser

str_parser = StrOutputParser()

# %%
# TASK-4  [Custom Runnable]  
from langchain_core.runnables import RunnableLambda

def dictionary_maker(text: str) -> dict:

 return{"text": text}

dictionary_maker_runnable = RunnableLambda(dictionary_maker)

# %%
# TASK-5 [Template For Post]

prompt_post = ChatPromptTemplate.from_messages(
[("system", "你是一个社会媒体帖子生成者。"),
("human", "请根据以下输入生成一个引人入胜的社交媒体帖子：{text}")])

# %%
# TASK-6 [Generate Post]

# llm_openai

# %%
# TASK-7 [StrParser For Post]

str_parser = StrOutputParser()

# %%
# CHAIN

chain = prompt_template | llm_openai | str_parser | dictionary_maker_runnable | prompt_post | llm_openai | str_parser

chain.invoke("猫咪冷知识")
# Out:
# '🐱 猫奴必看！关于主子的15个冷知识，你知道几个？  \n原来“喵喵叫”是专门发明给人类的语言，而它们的鼻纹居然像指纹一样独一无二…  \n更神奇的是，猫咪呼噜声可能是在自我疗愈，睡觉时其实大部分时间都在“假寐”！  \n快来看看这些让你惊呼“原来如此”的猫咪秘密👇  \n\n#猫咪冷知识 #养猫必看 #喵星人 #宠物知识'
