# %% [markdown]
# # **MESSAGE**

# %%
from langchain_core.messages import HumanMessage, SystemMessage,AIMessage
from langchain_openai import ChatOpenAI
import os

my_messages = [
   HumanMessage(content="Bro ,告诉我一个冷知识"),
    SystemMessage(content="你是一个有趣的助手"),
    ]

llm_openai = ChatOpenAI(
    api_key=os.environ.get('DEEPSEEK_API_KEY'),
        base_url="https://api.deepseek.com",
    model="deepseek-chat",
    temperature=0,
)

llm_openai.invoke(my_messages).content
# Out:
# '当然！这里有一个关于“打喷嚏时眼睛会闭上”的冷知识：\n\n**为什么打喷嚏时眼睛会不由自主地闭上？**  \n这其实是一种生理反射，被称为“喷嚏反射”。当鼻腔受到刺激时，大脑会通过神经信号触发一系列肌肉收缩，包括面部、胸部和腹部的肌肉，以快速排出异物。而眼轮匝肌（控制闭眼的肌肉）也会被连带激活，导致眼睛自动闭合。\n\n**可能的原因：**  \n1. **保护眼睛**：闭眼可以防止喷嚏喷出的高速气流或飞沫直接冲击眼球，避免细菌或异物进入眼睛。  \n2. **神经联动**：控制打喷嚏和闭眼的神经中枢在脑干中位置接近，信号容易“扩散”，形成连锁反应。  \n3. **肌肉协同**：面部肌肉在剧烈动作时（如打喷嚏、咳嗽）会自然收紧，闭眼是其中一部分。\n\n**有趣的是**：虽然闭眼是普遍现象，但理论上人也可以强行在打喷嚏时睁眼（不过非常困难，且不建议尝试）。另外，打喷嚏时心脏不会停跳，这只是常见的误解！\n\n下次打喷嚏时，可以留意一下这个“自动闭眼”的瞬间哦！ 😄'
