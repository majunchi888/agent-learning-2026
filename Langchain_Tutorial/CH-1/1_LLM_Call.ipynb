# %% [markdown]
# # **LLM CALL**

# %%
# Please install OpenAI SDK first: `pip3 install openai`
import os
from openai import OpenAI
import load_dotenv

load_dotenv()

client = OpenAI(
    api_key=os.environ.get('DEEPSEEK_API_KEY'),
    base_url="https://api.deepseek.com")

response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Bro ,can you tell me a joke?"},
    ],
    stream=False
)


print(response.choices[0].message.content)
# Out:
# Of course, bro! Here's one for you:
#
# Why don't scientists trust atoms?
#
# Because they make up *everything*.

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

if os.environ.get('DEEPSEEK_API_KEY') :
    print("DEEPSEEK_API_KEY is set")
else:    print("DEEPSEEK_API_KEY is not set")
# Out:
# DEEPSEEK_API_KEY is set

# %%
llm_openai = ChatOpenAI(
    api_key=os.environ.get('DEEPSEEK_API_KEY'),
        base_url="https://api.deepseek.com", 
    model="deepseek-chat",
    temperature=0)

llm_openai.invoke("Bro ,can you tell me a joke?").content

# %%
from langchain.chat_models import init_chat_model

llm_openai = init_chat_model(
    api_key=os.environ.get('DEEPSEEK_API_KEY'),
        base_url="https://api.deepseek.com",
         model_provider="deepseek",  
    model="deepseek-chat",
    temperature=0
)
llm_openai.invoke("Bro ,can you tell me a joke?").content
# Out:
# 'Of course, bro. Here\'s a classic one for you:\n\nA man is sitting at home when he hears a knock at the door.  \nHe opens it and sees a snail on the porch. He picks up the snail and throws it as far as he can.\n\nThree years later, there’s a knock on the door. He opens it, and the same snail is there.  \nThe snail looks up at him and says, *"What the hell was that all about?"*'
